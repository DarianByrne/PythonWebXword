# %%
import DBcm

# %%
creds = {
    "user": "xworduser",
    "password": "xwordpasswd",
    "host": "localhost",
    "database": "xwordDB",
}

# %%
with DBcm.UseDatabase(creds) as db:
    SQL = "describe log"
    db.execute(SQL)
    res = db.fetchall()

# %%
type(res)
# Out:
# list

# %%
res
# Out:
# [('ts', 'timestamp', 'YES', '', 'current_timestamp()', ''),
#  ('pattern', 'varchar(64)', 'YES', '', None, ''),
#  ('matches', 'int(11)', 'YES', '', None, '')]

# %%
for line in res:
    print(line)
    print("-"*40)
# Out:
# ('ts', 'timestamp', 'YES', '', 'current_timestamp()', '')
# ----------------------------------------
# ('pattern', 'varchar(64)', 'YES', '', None, '')
# ----------------------------------------
# ('matches', 'int(11)', 'YES', '', None, '')
# ----------------------------------------

# %%
with DBcm.UseDatabase(creds) as db:
    SQL = "select count(*) from log"
    db.execute(SQL)
    res = db.fetchall()
res
# Out:
# [(3,)]

# %%
res[0]
# Out:
# (3,)

# %%
type((42))
# Out:
# int

# %%
type((42,))
# Out:
# tuple

# %%
pattern = "_yt__n"
matches = 42

# %%
import xword

# %%
xword.matches(pattern)
# Out:
# (['lytten', 'lytton', 'python'], 3)

# %%
SQL = """
    insert into log
    (pattern, matches)
    values
    ("_yt__n", 3)
"""

# %%
with DBcm.UseDatabase(creds) as db:
    db.execute(SQL)

# %%
pattern = "x_____ing"

xword.matches(pattern)
# Out:
# ([], 0)

# %%
SQL = """
    insert into log
    (pattern, matches)
    values
    ("x_____ing", 0)
"""

# %%
with DBcm.UseDatabase(creds) as db:
    db.execute(SQL)

# %%
# %s is a data placeholder.

SQL = """
    insert into log
    (pattern, matches)
    values
    (%s, %s)
"""

# %%
print(SQL)
# Out:
#     insert into log
#     (pattern, matches)
#     values
#     (%s, %s)

# %%
pattern = "ext__"
xword.matches(pattern)
# Out:
# (['extol', 'exton', 'extra'], 3)

# %%
xword.matches(pattern)[-1]
# Out:
# 3

# %%
with DBcm.UseDatabase(creds) as db:
    db.execute(SQL, (pattern, xword.matches(pattern)[-1]))

# %%
SQL = """
    select *
    from log
"""

with DBcm.UseDatabase(creds) as db:
    db.execute(SQL)
    res = db.fetchall()
res
# Out:
# [(datetime.datetime(2025, 11, 24, 17, 27, 6), '_yt__n', 3),
#  (datetime.datetime(2025, 11, 24, 17, 28, 43), 'x_____ing', 0),
#  (datetime.datetime(2025, 11, 24, 17, 31, 28), 'ext__', 3)]

# %%
import model

# %%
model.get_log_data()
# Out:
# [(datetime.datetime(2025, 11, 24, 17, 27, 6), '_yt__n', 3),
#  (datetime.datetime(2025, 11, 24, 17, 28, 43), 'x_____ing', 0),
#  (datetime.datetime(2025, 11, 24, 17, 31, 28), 'ext__', 3)]

# %%
model.add_to_database("xyz", 0)

# %%
model.get_log_data()
# Out:
# [(datetime.datetime(2025, 11, 24, 17, 27, 6), '_yt__n', 3),
#  (datetime.datetime(2025, 11, 24, 17, 28, 43), 'x_____ing', 0),
#  (datetime.datetime(2025, 11, 24, 17, 31, 28), 'ext__', 3),
#  (datetime.datetime(2025, 11, 24, 17, 51, 36), 'xyz', 0)]
